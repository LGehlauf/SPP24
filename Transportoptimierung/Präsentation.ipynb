# %% [markdown]
# ## Fertigungsaufbau
# - Werkstattfertigung mit 5 Betriebsmittelgruppen (jeweils 1-2 Betriebsmittel)
# - 7 Produkte mit ihren jeweiligen Arbeitsplänen in DB definiert
# - Erzeugung der Aufträge über Bestellbestandsverfahren entsprechend der generierten Entnahmen aus Fertigteillager
# - Auftragsfreigabe durch Engpasssteuerung implementiert
# - Transporte durch drei Transportfahrzeuge (jeweils mit unteschiedlichen Geschwindigkeiten und Akkukapazitäten) ausgeführt
# - Definition eines Graphen und Einsatz des Dijkstra-Algorithmus zur Berechnung der kürzesten Transportwege
# - Simulation von Auschüssen durch Ziehen von Zufallszahlen aus Binomialverteilung
# - Simulation von Bearbeitungszeiten durch Ziehen von Zufallszahlen aus Log.-Normalverteilung
# - Simulation von Maschinenausfällen durch Ziehen von Zufallszahlen aus Weibullverteilung
# - Implementierung eines Betriebskalenders, welcher Feiertage und Wochenende sowie wählbare Schichtregime berücksichtigt und die Produktion dementsprechend pausiert
# - Möglichkeit zur Defnition einer Liste zusätzlicher Aufträge

# %% [markdown]
# ## Projekt Organisation

# %% [markdown]
# <div style="text-align: center;">
#     <img src="Pictures/Methodik.jpg" alt="DB-Schema.jpg" style="width: 1000px;"/>
# </div>

# %% [markdown]
# ## Visualisierung

# %%
import gui
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.15)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# c:\Users\Karl Marbach\.conda\envs\anomalib\lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## Auswertung zur Verfügbarkeit und den Durchlaufzeiten

# %%
from Dashboard import Plantafel, Dashboard
Dashboard()

# %% [markdown]
# ## Feinterminierung

# %%
Plantafel("2024-02-06 06:00:00", "2024-02-08 22:00:00")
# Out:
# /Users/karl/SPP24/Transportoptimierung/Dashboard.py:269: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ## Experimente Produktionskennlinie
# ### Idealer Produktionsprozess am Engpass
# <div style="text-align: center;">
#     <img src="Pictures/ideales_durchlaufdiagramm.jpg" alt="DB-Schema.jpg" style="width: 600px;"/>
# </div>

# %% [markdown]
# ### Realle Produktionskennlinie (theoretisch)
# <div style="text-align: center;">
#     <img src="Pictures/reale produktionskennlinie.jpg" alt="DB-Schema.jpg" style="width: 600px;"/>
# </div>

# %% [markdown]
# ### Realle Produktionskennlinie (experimentell)
# <div style="display: flex; justify-content: center;">
#     <img src="Pictures/simulation_nr1.jpg" alt="Simulation 1" style="width: 45%; margin: 5px;">
#     <img src="Pictures/simulation_nr2.jpg" alt="Simulation 2" style="width: 45%; margin: 5px;">
# </div>
# <div style="display: flex; justify-content: center;">
#     <img src="Pictures/simulation_nr3.jpg" alt="Simulation 3" style="width: 45%; margin: 5px;">
#     <img src="Pictures/simulation_nr4.jpg" alt="Simulation 4" style="width: 45%; margin: 5px;">
# </div>
# <div style="display: flex; justify-content: center;">
#     <img src="Pictures/simulation_nr5.jpg" alt="Simulation 5" style="width: 45%; margin: 5px;">
#     <img src="Pictures/simulation_nr6.jpg" alt="Simulation 6" style="width: 45%; margin: 5px;">
# </div>

# %% [markdown]
# ### Aufstellung der Kennlinie und logistische Positionierung
# <div style="text-align: center;">
#     <img src="Pictures/reale produktionskennlinie_2.jpg" alt="DB-Schema.jpg" style="width: 600px;"/>
# </div>

# %% [markdown]
# ## Weiteres Vorgehen
# - Ermittlung und Optimierung der Transportauslastung
# - Überführung der Simulations-Engine und der Auswertung in eine .exe, um Simulation und Auswertungen extern steuern zu können
# - weitere Experimente?
